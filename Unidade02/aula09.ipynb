# %% [markdown]
# <a href="https://colab.research.google.com/github/deboramendonca18/engenharia-de-prompt-e-aplicao-em-IA/blob/main/aula09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PARECER TÉCNICO: PRÁTICAS DE DESENVOLVIMENTO E IA (UNIDADE II)
#
# PARA: Coordenação do Curso / Prof. Kadidja Valéria
#
# DE: Débora Mendonça
#
# DATA: 27 de Abril de 2026
#
# 1. INTRODUÇÃO
#
# Este parecer apresenta uma análise das atividades desenvolvidas durante a Unidade II, focando na integração de ferramentas de Inteligência Artificial Generativa no fluxo de trabalho de programação. O objetivo é relatar como a automação, a refatoração e a ética no uso de IAs foram aplicadas para otimizar processos acadêmicos e técnicos, unindo a teoria discutida nos materiais de apoio, com a prática de codificação.
#
# 2. DESENVOLVIMENTO E PRÁTICAS REALIZADAS
#
# 2.1 Automação de Tarefas
# Como atividade prática principal, desenvolvi um script de automação em Python utilizando o ambiente Google Colab. O código executa a organização sistemática de diretórios, realizando a triagem de arquivos e movendo-os para pastas específicas baseadas em suas extensões (PDF, imagens, scripts, etc.).
# Impacto no Workflow: A automação eliminou a necessidade de triagem manual, demonstrando como a integração de lógica de programação com necessidades cotidianas, pode elevar drasticamente a produtividade.
#
# 2.2 REFATORAÇÃO E TRIANGULAÇÃO DE IA’S
#
# Durante a unidade, apliquei uma técnica de filtragem de refatoração multiplataforma. O processo consistiu em, submeter o mesmo trecho de código ao Gemini, Claude e ChatGPT para identificar erros recorrentes e captar diferentes sugestões de otimização.
# Resultado: Esta prática permitiu comparar as abordagens de cada modelo, resultando em um código mais robusto, legível e eficiente. A experiência confirmou que a eficácia da ferramenta está diretamente ligada à Engenharia de Prompt e à capacidade do desenvolvedor em fornecer instruções assertivas.
#
# 2.3 FERRAMENTAS DE INTEGRAÇÃO
#
# Google Colab & GitHub: A integração entre essas ferramentas foi um ponto chave. A capacidade de desenvolver, testar e realizar o commit diretamente para o GitHub otimizou o tempo de entrega e a organização do portfólio acadêmico.
# Gemini: A ferramenta mostrou-se altamente colaborativa, apresentando uma interface intuitiva e baixa margem de erro para a lógica de automação proposta.
#
# 3. ANÁLISE CRÍTICA E ÉTICA
#
# A relação com a IA evoluiu de uma visão puramente assistencial para uma colaboração técnica estratégica. Do ponto de vista ético, a prática de validar o código em diferentes IAs e revisar manualmente cada sugestão garante que o desenvolvedor mantenha o protagonismo e a responsabilidade sobre o produto final. O uso das IAs serviu como um "tutor de programação", auxiliando na compreensão de boas práticas e na redução de dívidas técnicas no código.
#
# 4. CONCLUSÃO
#
# A experiência na Unidade II foi extremamente positiva. A transição para um workflow que utiliza IA para refatoração e o Google Colab para prototipagem rápida elevou o nível dos projetos desenvolvidos, tornando-os mais profissionais, escaláveis e bem estruturados. Sem contar que a teoria + a prática ministrada em sala pela profa. Kadidja, colaborou muito para o meu aperfeiçoamento na estrutura dos prompts e execução em IA´s.
#
# 5. TRANSPARÊNCIA: FONTES E APOIO DE IA
#
# Conforme os requisitos de transparência da atividade, informo as ferramentas que apoiaram este trabalho:
# Gemini (Google): Utilizado para a estruturação gramatical deste parecer, revisão do script de automação e lógica de organização de diretórios.
# ChatGPT & Claude: Utilizados na etapa de refatoração comparativa e detecção de erros de sintaxe.
# Google Colab: Ambiente principal de desenvolvimento, execução e integração com GitHub.
